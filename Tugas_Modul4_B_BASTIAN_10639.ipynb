# %%
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import logging
logging.getLogger('matplotlib.font_manager').disabled = True

credit = pd.read_csv(r'E:\SEMESTER 9\PMDPM\4\Tugas4_B_10639\credit_card.csv')
credit.head(10)
# Out:
#    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0      1         87073            100000                   2
# 1      2         38414             50000                   3
# 2      3         17341             50000                   7
# 3      4         40496             30000                   5
# 4      5         47437            100000                   6
# 5      6         58634             20000                   3
# 6      7         48370            100000                   5
# 7      8         37376             15000                   3
# 8      9         82490              5000                   2
# 9     10         44770              3000                   4
#
#    Total_visits_bank  Total_visits_online  Total_calls_made
# 0                  1                    1                 0
# 1                  0                   10                 9
# 2                  1                    3                 4
# 3                  1                    1                 4
# 4                  0                   12                 3
# 5                  0                    1                 8
# 6                  0                   11                 2
# 7                  0                    1                 1
# 8                  0                    2                 2
# 9                  0                    1                 7

# %%
print("data null \n",df_credit.isnull().sum())
print("data kosong \n",df_credit.empty)
print("data nan \n",df_credit.isna().sum())
# Out:
# data null
#  Sl_No                  0
# Customer Key           0
# Avg_Credit_Limit       0
# Total_Credit_Cards     0
# Total_visits_bank      0
# Total_visits_online    0
# Total_calls_made       0
# dtype: int64
# data kosong
#  False
# data nan
#  Sl_No                  0
# Customer Key           0
# Avg_Credit_Limit       0
# Total_Credit_Cards     0
# Total_visits_bank      0
# Total_visits_online    0
# Total_calls_made       0
# dtype: int64

# %%
df_credit=credit.drop(['Customer Key','Sl_No'], axis=1)
df_credit.head(20)
# Out:
#     Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 0             100000                   2                  1
# 1              50000                   3                  0
# 2              50000                   7                  1
# 3              30000                   5                  1
# 4             100000                   6                  0
# 5              20000                   3                  0
# 6             100000                   5                  0
# 7              15000                   3                  0
# 8               5000                   2                  0
# 9               3000                   4                  0
# 10             10000                   4                  0
# 11             13000                   3                  0
# 12             11000                   1                  2
# 13              9000                   1                  1
# 14              6000                   2                  2
# 15              8000                   2                  0
# 16             15000                   2                  1
# 17              8000                   2                  0
# 18             11000                   2                  2
# 19             19000                   4                  1
#
#     Total_visits_online  Total_calls_made
# 0                     1                 0
# 1                    10                 9
# 2                     3                 4
# 3                     1                 4
# 4                    12                 3
# 5                     1                 8
# 6                    11                 2
# 7                     1                 1
# 8                     2                 2
# 9                     1                 7
# 10                    5                 5
# 11                    2                 7
# 12                    5                 9
# 13                    5                 6
# 14                    4                 6
# 15                    5                 7
# 16                    2                 4
# 17                    3                 4
# 18                    2                 7
# 19                    5                 8

# %%
df_credit['Avg_Credit_Limit'].plot(kind='box')
# Out:
# <Axes: >

# %%
from pandas.api.types import is_numeric_dtype

def remove_outlier(data_frame, kolom_outlier):
    df_out=data_frame.copy()
    if is_numeric_dtype(data_frame[kolom_outlier]):
        q1=data_frame[kolom_outlier].quantile(0.25)
        q3=data_frame[kolom_outlier].quantile(0.75)
            
        iqr=q3-q1
        upper=q3+(1.5*iqr)
        lower=q1-(1.5*iqr)
        df_out=df_out.loc[(data_frame[kolom_outlier]>=lower)&(data_frame[kolom_outlier]<=upper)]
    return df_out

data_bersih=remove_outlier(df_credit,"Avg_Credit_Limit")
print("Jumlah data sebelum dibuang outlier : ",df_credit.shape[0])
print("Jumlah data sebelum dibuang outlier : ",data_bersih.shape[0])
data_bersih['Avg_Credit_Limit'].plot(kind='box')
# Out:
# Jumlah data sebelum dibuang outlier :  660
# Jumlah data sebelum dibuang outlier :  621
# <Axes: >

# %%
import warnings
warnings.filterwarnings('ignore')
from yellowbrick.cluster import KElbowVisualizer

kMeansC= KMeans(random_state=63)
vis= KElbowVisualizer(kMeansC, k=(2,11))
vis.fit(data_bersih)

vis.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
from yellowbrick.cluster import SilhouetteVisualizer

fig, ax= plt.subplots(9,1, figsize=(15,20))

for k in np.arange(2,11):
    kMeansC=KMeans(n_clusters=k, init='k-means++', random_state=63)
    KM_clusters=kMeansC.fit_predict(data_bersih)
    print("Silhouette Score K-Means for",k," clusters", silhouette_score(data_bersih, KM_clusters))
    
    
    sil_vis=SilhouetteVisualizer(kMeansC, colors='yellowbrick', ax=ax[k-2])
    sil_vis.fit(data_bersih)
    
    ax[k-2].set(xlabel="Silhouette Score of each samples ", ylabel="Cluster label")
# Out:
# Silhouette Score K-Means for 2  clusters 0.7254150167909509
# Silhouette Score K-Means for 3  clusters 0.7058100919802311
# Silhouette Score K-Means for 4  clusters 0.5866654641248105
# Silhouette Score K-Means for 5  clusters 0.5986950720392292
# Silhouette Score K-Means for 6  clusters 0.6176747811139572
# Silhouette Score K-Means for 7  clusters 0.6200545090772941
# Silhouette Score K-Means for 8  clusters 0.6163567935085081
# Silhouette Score K-Means for 9  clusters 0.5949266725727135
# Silhouette Score K-Means for 10  clusters 0.5858799962790895

# %%
data_bersih.columns
# Out:
# Index(['Avg_Credit_Limit', 'Total_Credit_Cards', 'Total_visits_bank',
#        'Total_visits_online', 'Total_calls_made'],
#       dtype='object')

# %%
Kmeans= KMeans(n_clusters=3, init='k-means++', random_state=39)

KM_clusters=Kmeans.fit_predict(data_bersih)

#Graph 3D

fig=plt.figure()
ax=plt.axes(projection='3d')

cluster_colors={0: 'red', 1:'yellow', 2:'green', 3:'blue',4:'magenta', 5:'black',6:'cyan'}

ax.scatter(data_bersih['Avg_Credit_Limit'], data_bersih['Total_Credit_Cards'], data_bersih['Total_visits_online'], c=[cluster_colors[i] for i in KM_clusters], s=100)

plt.title('Segmentasi Nasabah berdasarkan K-Means')
ax.set_xlabel('Average Credit Limit') #sumbu x
ax.set_ylabel('Total Credit Cards') #sumbu y
ax.set_zlabel('Total Visits Online') #sumbu z

plt.show()

print("Slihouette score K-Means : %0.3f" %silhouette_score(data_bersih, KM_clusters))
# Out:
# Slihouette score K-Means : 0.706

# %%
import seaborn as sns
from matplotlib.colors import ListedColormap


AGG = AgglomerativeClustering(n_clusters=3, linkage='ward')


AGG_clusters=AGG.fit_predict(data_bersih)
cmap= ListedColormap(sns.color_palette("plasma", 256).as_hex())

#Graph 3D

fig=plt.figure()
ax=plt.axes(projection='3d')


ax.scatter(data_bersih['Avg_Credit_Limit'], data_bersih['Total_Credit_Cards'], data_bersih['Total_visits_online'], c=AGG_clusters,cmap=cmap, s=100)

plt.title('Segmentasi Nasabah berdasarkan AGG')
ax.set_xlabel('Average Credit Limit') #sumbu x
ax.set_ylabel('Total Credit Cards') #sumbu y
ax.set_zlabel('Total Visits Online') #sumbu z

plt.show()

print("Slihouette score AGG : %0.3f" %silhouette_score(data_bersih, AGG_clusters))
# Out:
# Slihouette score AGG : 0.705

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
linkage_array= linkage(data_bersih, method='ward')
dendrogram(linkage_array)


plt.xlabel('Sample Index')
plt.ylabel("Cluster distance")

plt.show()

# %%
DBSC= DBSCAN(min_samples=20, eps=2500)

DBSC_clusters= DBSC.fit_predict(data_bersih)

from matplotlib.colors import ListedColormap

cmap=ListedColormap(sns.color_palette("rocket",256).as_hex())

fig=plt.figure()
ax=plt.axes(projection='3d')

ax.scatter(data_bersih['Avg_Credit_Limit'], data_bersih['Total_Credit_Cards'], data_bersih['Total_visits_online'], c=DBSC_clusters,cmap=cmap, s=100)

plt.title('Segmentasi Nasabah berdasarkan DBSCAN')
ax.set_xlabel('Average Credit Limit') #sumbu x
ax.set_ylabel('Total Credit Cards') #sumbu y
ax.set_zlabel('Total Visits Online') #sumbu z

plt.show()

print("Slihouette score DBSCAN : %0.3f" %silhouette_score(data_bersih, DBSC_clusters))
# Out:
# Slihouette score DBSCAN : 0.657

# %%
import pickle

with open('KMeans_model.pkl','wb')as r:
    pickle.dump((Kmeans),r)

with open('AGG_model.pkl','wb')as r:
    pickle.dump((AGG),r)
with open('DBSCAN_model.pkl','wb')as r:
    pickle.dump((DBSC),r)
    
print("Model berhasil disimpan")
# Out:
# Model berhasil disimpan
